# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading and printing the Bike Sales Dashboard Dataset

# %%
data = pd.read_excel("Bike Sales Dashboard.xlsx")

# %% [markdown]
# Bar Chart: Frequency of a categorical column (e.g., "Purchased Bike")

# %%
# Bar Chart for "Purchased Bike"
plt.figure(figsize=(8, 6))
data['Purchased Bike'].value_counts().plot(kind='bar', color=['red', 'green'], edgecolor='black')
plt.title('Frequency of Purchased Bike')
plt.xlabel('Purchased Bike')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Line Graph: Trend of numerical data (e.g., Age vs Income)

# %%
plt.figure(figsize=(10, 6))
data.sort_values('Age', inplace=True)
plt.plot(data['Age'], data['Income'], color='maroon', alpha=0.5)
plt.title('Income Trend by Age')
plt.xlabel('Age')
plt.ylabel('Income')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Line Graph: Trend of numerical data (e.g., Age vs Income)

# %%
plt.figure(figsize=(10, 6))
data.sort_values('Age', inplace=True)
plt.plot(data['Age'], data['Income'], color='orange', alpha=0.5)
plt.title('Income Trend by Age')
plt.xlabel('Age')
plt.ylabel('Income')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Pie Chart: Distribution of categorical data (e.g., "Commute Distance")

# %%
plt.figure(figsize=(8, 8))
data['Commute Distance'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'orange', 'green', 'red', 'purple'])
plt.title('Distribution of Commute Distance')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# Finding missing values

# %%
missing_values = data.isnull().sum()

columns_with_missing = missing_values[missing_values > 0]

print("Missing values in each column:")
print(missing_values)

if len(columns_with_missing) > 0:
    print("\nColumns with missing values:")
    print(columns_with_missing)
else:
    print("\nNo missing values in the dataset.")
# Out:
# Missing values in each column:
# ID                  0
# Martial Status      0
# Gender              0
# Income              0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Age Brackets        0
# Purchased Bike      0
# dtype: int64
#
# No missing values in the dataset.

# %% [markdown]
# Correlation heat-map with each column.

# %%
file_path = 'Bike Sales Dashboard.xlsx'
data = pd.read_excel(file_path, sheet_name='bike_buyers')

numerical_data = data.select_dtypes(include=['number'])

correlation_matrix = numerical_data.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, )
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()
